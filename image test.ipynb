# %%
import numpy
import matplotlib.pyplot as plt
from skimage.transform import AffineTransform as affineTransform
from skimage.feature import canny
from scipy.ndimage import binary_fill_holes
from skimage.transform import warp
from math import pi

# %matplotlib inline

# %%
x = numpy.load('../data/ex2/res/102')

# %%
for i in range(len(x[1])):
    im0 = x[1][i]
    for j in numpy.arange(-10, 10)*pi/180:
        tf = affineTransform(shear = j, )
        im = warp(im0, tf)
        plt.imshow(im.transpose())
        plt.show()
        raw_input()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-ced57290fba6> in <module>()
#       6         plt.imshow(im.transpose())
#       7         plt.show()
# ----> 8         raw_input()
#       9
#
# /home/sxz8564/virtualenvs/myenv/lib/python2.7/site-packages/IPython/kernel/zmq/kernelbase.pyc in raw_input(self, prompt)
#     649             self._parent_ident,
#     650             self._parent_header,
# --> 651             password=False,
#     652         )
#     653
#
# /home/sxz8564/virtualenvs/myenv/lib/python2.7/site-packages/IPython/kernel/zmq/kernelbase.pyc in _input_request(self, prompt, ident, parent, password)
#     679             except KeyboardInterrupt:
#     680                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 681                 raise KeyboardInterrupt
#     682             else:
#     683                 break
#
# ...

# %%
img = numpy.random.rand(10, 10)
img = numpy.uint8(img > 0.5)
img_filled = binary_fill_holes(img)
img_edge = canny(numpy.uint8(img_filled)*255)

# %%
plt.imshow(img, interpolation = 'nearest')
plt.show()
plt.imshow(img_filled, interpolation = 'nearest')
plt.show()
plt.imshow(img_edge, interpolation = 'nearest')
plt.show()

# %%
img_edge
# Out:
# array([[False, False, False, False, False, False, False, False, False,
#         False],
#        [False,  True, False,  True, False,  True,  True, False, False,
#         False],
#        [False, False, False, False, False, False, False, False,  True,
#         False],
#        [False,  True,  True,  True,  True, False,  True,  True,  True,
#         False],
#        [False, False, False, False,  True,  True, False, False,  True,
#         False],
#        [False, False,  True, False, False,  True, False,  True,  True,
#         False],
#        [False,  True,  True, False, False,  True, False, False, False,
#         False],
#        [False,  True, False, False,  True,  True, False, False, False,
#         False],
#        [False,  True, False,  True,  True, False,  True,  True,  True,
#         False],
#        [False, False, False, False, False, False, False, False, False,
#         False]], dtype=bool)

# %%
from scipy.misc import imread
import matplotlib.pyplot as plt
import pickle
# %matplotlib inline
im = imread('1080.jpg')
plt.imshow(im)
roi = [im]
pickle.dump(roi, open('../data/ex3/roi/img_1080', 'w'))

# %%
3/25.0
# Out:
# 0.12
