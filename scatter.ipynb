# %%
import sys
sys.path.insert(0, '../python')
import arrayOp
from fileOp import pickle_load
from imgOp import imShow

# %%
s = pickle_load('img_228', '../data/ex1/res/')[0]
im = arrayOp.stack2image(s)
imShow(im.transpose())

# %%
thre = 250
xs, ys = arrayOp.stack2scatter(s, thre)

# %%
fig, ax = subplots(figsize = (5, 5))
for x, y in zip(xs, ys):
        plt.scatter(x, y)

# %%
plt.scatter(xs[19], ys[19])

# %%
imShow(s[17])

# %%
y
# Out:
# array([1, 2, 0, 1, 2, 0])
